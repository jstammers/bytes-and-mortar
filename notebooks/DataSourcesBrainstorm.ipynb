# %% [markdown]
# # List of possible sources of data

# %% [markdown]
# (1)
#
# __title__: price-paid
#
# __description__: "Our Price Paid Data includes information on all property sales in England and Wales that are sold for value and are lodged with us for registration."
#
# __links__:
# 1. https://www.gov.uk/government/statistical-data-sets/price-paid-data-downloads
# 2. https://www.kaggle.com/hm-land-registry/uk-housing-prices-paid
#
# (2)
#
# __title__: Dwelling stock
#
# __description__: Dwelling stock by type and possibly district. (As excel files not csvs and split by England/NI/Wales/Scotland)
#
# __link__: https://www.gov.uk/government/statistical-data-sets/live-tables-on-dwelling-stock-including-vacants
